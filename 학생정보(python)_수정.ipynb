# %%
import pandas as pd
# colnames = ["프로젝트멘토배정기업", "성함", "성별", "연락처", "이메일", "생년월일", "최종전공명"]
info = pd.read_csv("/Users/junsangwon/Desktop/profile_korean.csv", encoding = 'utf-8', names=colnames)
info
# Out:
#        프로젝트멘토배정기업   성함  성별            연락처                        이메일    생년월일  \
# 0   프로젝트 멘토 배정 기업   성함  성별            연락처                        이메일    생년월일
# 1          11시11분  박건희  남자  010-4148-0000       ddpgunhi23@naver.com  950100
# 2          11시11분  박규란  여자  010-5527-0000        gyul_hana@naver.com  950800
# 3          11시11분  원준상  남자  010-4399-0000          0504won@naver.com  930500
# 4          5Works  노홍민  남자  010-6219-0000       nhmnhm0819@naver.com  940800
# 5          5Works  오윤석  남자  010-8742-0000        iapetos45@naver.com  940400
# 6        메가존 클라우드  김지호  남자  010-5017-0000          jck1461@naver.com  951100
# 7        메가존 클라우드  박정현  여자  010-2359-0000      parkje09270@gmail.com  950900
# 8        메가존 클라우드  서아로  여자  010-7370-0000           tjdkfh@naver.com  960600
# 9        메가존 클라우드  이상아  여자  010-5029-0000         dktkd237@naver.com  960300
# 10       메가존 클라우드  이정진  남자  010-5163-0000     jeongjeanlee@gmail.com  940400
# ...

# %%
names = info.성함.tolist()
sexs = info.성별.tolist()
births = info.생년월일.tolist()
emails = info.이메일.tolist()
mentors = info.프로젝트멘토배정기업.tolist()
phones = info.연락처.tolist()
majors = info.최종전공명.tolist()

# %%
a = names
print("a:", type(a))
b = sexs
print(type(b))
c = births
print(type(c))
d = emails
print(type(d))
e = mentors
print(type(e))
f = phones
print(type(f))
g = majors
print(type(g))
# Out:
# a: <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
def name():
    a = input("성명을 입력해주세요.\n")
    i = 0
    b = names
    if a in b:
        while i <= 25:
            if a == info.loc[i].iloc[1]:
                print(info.loc[i])
                i = i + 1
            else:
                i = i + 1
        else:
            print("검색이 완료되었습니다")
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        name()

# %%
def sex():
    a = input("성별을 입력해주세요.\n(남자, 여자)\n")
    i = -1
    if a == "남자":
        while i <= 24:
            i = i + 1
            info.loc[i].iloc[2]
            if a == info.loc[i].iloc[2]:
                print(info.loc[i])
                
    elif a == "여자":
        while i <= 24:
            i = i + 1
            info.loc[i].iloc[2]
            if a == info.loc[i].iloc[2]:
                print(info.loc[i])
                
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        return sex()

# %%
def birth():
    a = input("생년월일을 입력해주세요.\n(ex. 1990년 2월 14일 -> 900214)\n")
    i = 0
    b = births
    if a in b:
        while i <= 25:
            if a == info.loc[i].iloc[5]:
                print(info.loc[i])
                i = i + 1
            else:
                i = i + 1
        else:
            print("검색이 완료되었습니다")
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        birth()

# %%
def email():
    a = input("이메일을 입력해주세요.\n")
    i = 0
    b = emails
    if a in b:
        while i <= 25:
            if a == info.loc[i].iloc[4]:
                print(info.loc[i])
                i = i + 1
            else:
                i = i + 1
        else:
            print("검색이 완료되었습니다")
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        email()

# %%
def mentor():
    a = input("멘토기업을 입력해주세요.\n(1.11시11분, 2.5Works, 3.메가존 클라우드, 4.모코엠시스, 5.시네틱스, 6.씨닷츠)\n")
    i = 0
    b = mentors
    if a in b:
        while i <= 25:
            if a == info.loc[i].iloc[0]:
                print(info.loc[i])
                i = i + 1
            else:
                i = i + 1
        else:
            print("검색이 완료되었습니다")
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        mentor()

# %%
def phone():
    a = input("전화번호을 입력해주세요.\n(ex. 010-1234-5678)\n")
    i = 0
    b = phones
    if a in b:
        while i <= 25:
            if a == info.loc[i].iloc[3]:
                print(info.loc[i])
                i = i + 1
            else:
                i = i + 1
        else:
            print("검색이 완료되었습니다")
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        phone()

# %%
def major():
    a = input("전공을 입력해주세요.\n")
    i = 0
    b = majors
    if a in b:
        while i <= 25:
            if a == info.loc[i].iloc[6]:
                print(info.loc[i])
                i = i + 1
            else:
                i = i + 1
        else:
            print("검색이 완료되었습니다")
    else:
        print("잘못된 정보 입니다. 다시 입력해주세요.")
        major()

# %%
def call():
    x = input("KSA 혁신성장 과정 학생 정보 시스템\n(검색을 원하시는 메뉴 번호를 입력해주세요)\n1.성명\n2.성별\n3.생년월일\n4.이메일\n5.멘토\n6.전화번호\n7.전공\n")
    if x == "1":
        name()
        
    elif x == "2":
        sex()
        
    elif x == "3":
        birth()
        
    elif x == "4":
        email()
        
    elif x == "5":
        mentor()
        
    elif x == "6":
        phone()
        
    elif x == "7":
        major()
        
    else:
        print("잘못된 정보 입니다. 다시 눌러주세요.")
        return call()

# %%
call()
